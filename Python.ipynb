# %%
#Q1. Print Welcome
print("Welcome")
# Out:
# Welcome

# %%
#Q2. Print the given word
word = input("Enter word: ")
print(word)
# Out:
# Enter word: nave
# nave

# %%
#Q3. Print the given message
message = input("Enter message: ")
print(message)
# Out:
# Enter message: hi
# hi

# %%
#Q4. Print the given integer number
num = int(input("Enter integer: "))
print(num)
# Out:
# Enter integer: 123
# 123

# %%
#Q5. Print the given fractional number
num = float(input("Enter fractional number: "))
print(num)
# Out:
# Enter fractional number: 50
# 50.0

# %%
#Q6. Print fractional number in 2 digit decimal format
num = float(input("Enter number: "))
print("{:.2f}".format(num))
# Out:
# Enter number: 5
# 5.00

# %%
#Q7. Print integer number in hexadecimal format
num = int(input("Enter integer: "))
print(hex(num))
# Out:
# Enter integer: 2278
# 0x8e6

# %%
#Q8. Print integer number in octal format
num = int(input("Enter integer: "))
print(oct(num))
# Out:
# Enter integer: 2278
# 0o4346

# %%
#Q9. Print hexadecimal number in integer format
hex_num = input("Enter hexadecimal value: ")
print(int(hex_num, 16))
# Out:
# Enter hexadecimal value: 50
# 80

# %%
#Q10. Print octal number in integer format
oct_num = input("Enter octal value: ")
print(int(oct_num, 8))
# Out:
# Enter octal value: 20
# 16

# %%
#Q11. Print ASCII value of a character
ch = input("Enter character: ")
print(ord(ch))
# Out:
# Enter character: 1
# 49

# %%
#Q12. Print character for given ASCII value
ascii_value = int(input("Enter ASCII value: "))
print(chr(ascii_value))
# Out:
# Enter ASCII value: 5

# %%
#Q13. Print two numbers with space
a = 10
b = 20
print(a, b)
# Out:
# 10 20

# %%
#Q14. Print two numbers with tab space
a = 10
b = 20
print(a, "\t", b)
# Out:
# 10 	 20

# %%
#Q15. Print two numbers in two lines
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
#Q16. Print character in single quotes
ch = 'A'
print("'" + ch + "'")
# Out:
# 'A'

# %%
#Q17. Print two words in double quotes
print("\"Hello\" \"World\"")
# Out:
# "Hello" "World"

# %%
#Q18. Print date of birth (DD/MM/YYYY)
print("15/08/2004")
# Out:
# 15/08/2004

# %%
#Q19. Print integer with plus sign
num = 25
print(f"+{num}")
# Out:
# +25

# %%
#Q20. Print size of char, int, float, double
import sys

print("Char:", sys.getsizeof('A'))
print("Int:", sys.getsizeof(10))
print("Float:", sys.getsizeof(10.5))
print("Double:", sys.getsizeof(10.555))
# Out:
# Char: 42
# Int: 28
# Float: 24
# Double: 24

# %%
#Q21. Print roll number and name
roll = 123
name = "John"

print("Roll No:", roll, ", Name:", name)
# Out:
# Roll No: 123 , Name: John

# %%
#Q22. Print marks in 5 subjects
print("Math = 90")
print("Science = 85")
print("English = 88")
print("Physics = 92")
print("Chemistry = 87")
# Out:
# Math = 90
# Science = 85
# English = 88
# Physics = 92
# Chemistry = 87

# %%
#Q23. Print blood group
print("Blood Group: O+")
# Out:
# Blood Group: O+

# %%
#Q24. Print current time HH:MM:SS
from datetime import datetime

now = datetime.now()
print(now.strftime("%H:%M:%S"))
# Out:
# 10:00:33

# %%
#Q25. Print address in multiple lines
print("No:12")
print("ABC Street")
print("Chennai")
print("Tamil Nadu")
print("India")
# Out:
# No:12
# ABC Street
# Chennai
# Tamil Nadu
# India
